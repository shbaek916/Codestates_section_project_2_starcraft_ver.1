# %% [markdown]
# ## data_preproccessing2 데이터에서 train.csv를 game_id 별로 조금씩 잘라서 살펴본 내용들입니다
# ## 주로 한 것들은 데이터가 어떻게 구성되어 있는지, event, event_contents 가 무슨 값을 가지고 있는지, 게임 특성상 생성한 유닛, 유닛이 실행한 마법/능력 등의 한 플레이어에 승패에 의미있는 자료들을 추출할 수 있는지 등을 살펴봤습니다

# %%
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.max_rows = 1140

# %%
gameid0 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/gameid0.csv')
gameid0
# Out:
#       game_id  winner  time  player species              event  \
# 0           0       1  0.00       0       T             Camera
# 1           0       1  0.00       1       T             Camera
# 2           0       1  0.02       0       T          Selection
# 3           0       1  0.02       0       T            Ability
# 4           0       1  0.14       0       T             Camera
# 5           0       1  0.14       0       T             Camera
# 6           0       1  0.14       0       T             Camera
# 7           0       1  0.14       0       T             Camera
# 8           0       1  0.14       0       T             Camera
# 9           0       1  0.14       0       T             Camera
# 10          0       1  0.15       0       T             Camera
# 11          0       1  0.15       0       T             Camera
# 12          0       1  0.15       0       T             Camera
# 13          0       1  0.15       0       T             Camera
# ...

# %%
player0 = gameid0[gameid0.player ==0]
player0
# Out:
#       game_id  winner  time  player species              event  \
# 0           0       1  0.00       0       T             Camera
# 2           0       1  0.02       0       T          Selection
# 3           0       1  0.02       0       T            Ability
# 4           0       1  0.14       0       T             Camera
# 5           0       1  0.14       0       T             Camera
# 6           0       1  0.14       0       T             Camera
# 7           0       1  0.14       0       T             Camera
# 8           0       1  0.14       0       T             Camera
# 9           0       1  0.14       0       T             Camera
# 10          0       1  0.15       0       T             Camera
# 11          0       1  0.15       0       T             Camera
# 12          0       1  0.15       0       T             Camera
# 13          0       1  0.15       0       T             Camera
# 14          0       1  0.16       0       T             Camera
# ...

# %%
import seaborn as sns

sns.histplot(player0.event)

# %%
set(player0.event)
# Out:
# {'Ability',
#  'AddToControlGroup',
#  'Camera',
#  'GetControlGroup',
#  'Right Click',
#  'Selection',
#  'SetControlGroup'}

# %%
player0.event.value_counts()
# Out:
# Camera               444
# Selection             50
# Right Click           35
# Ability               34
# GetControlGroup       24
# SetControlGroup        3
# AddToControlGroup      2
# Name: event, dtype: int64

# %%
player0[player0.event == 'Ability']
# Out:
#       game_id  winner  time  player species    event  \
# 3           0       1  0.02       0       T  Ability
# 19          0       1  0.27       0       T  Ability
# 27          0       1  0.31       0       T  Ability
# 37          0       1  0.35       0       T  Ability
# 87          0       1  1.00       0       T  Ability
# 101         0       1  1.03       0       T  Ability
# 104         0       1  1.09       0       T  Ability
# 136         0       1  1.25       0       T  Ability
# 184         0       1  2.14       0       T  Ability
# 198         0       1  2.20       0       T  Ability
# 226         0       1  2.32       0       T  Ability
# 252         0       1  2.43       0       T  Ability
# 329         0       1  3.00       0       T  Ability
# 369         0       1  3.19       0       T  Ability
# 384         0       1  3.22       0       T  Ability
# 423         0       1  3.30       0       T  Ability
# 442         0       1  3.34       0       T  Ability
# ...

# %%
player1 = gameid0[gameid0.player ==1]
player1[player1.event == 'Ability']
# Out:
#       game_id  winner  time  player species    event  \
# 29          0       1  0.33       1       T  Ability
# 43          0       1  0.37       1       T  Ability
# 56          0       1  0.40       1       T  Ability
# 63          0       1  0.41       1       T  Ability
# 124         0       1  1.21       1       T  Ability
# 223         0       1  2.30       1       T  Ability
# 235         0       1  2.35       1       T  Ability
# 311         0       1  2.52       1       T  Ability
# 336         0       1  3.06       1       T  Ability
# 367         0       1  3.18       1       T  Ability
# 406         0       1  3.25       1       T  Ability
# 489         0       1  3.46       1       T  Ability
# 503         0       1  3.49       1       T  Ability
# 537         0       1  3.58       1       T  Ability
# 576         0       1  4.10       1       T  Ability
# 593         0       1  4.15       1       T  Ability
# 663         0       1  4.34       1       T  Ability
# ...

# %%
"""Camera               444
Selection             50
Right Click           35
Ability               34
GetControlGroup       24
SetControlGroup        3
AddToControlGroup """
player1[player1.event == 'Camera']
# Out:
#       game_id  winner  time  player species   event  \
# 1           0       1  0.00       1       T  Camera
# 30          0       1  0.34       1       T  Camera
# 31          0       1  0.34       1       T  Camera
# 33          0       1  0.34       1       T  Camera
# 34          0       1  0.35       1       T  Camera
# 35          0       1  0.35       1       T  Camera
# 36          0       1  0.35       1       T  Camera
# 44          0       1  0.38       1       T  Camera
# 45          0       1  0.38       1       T  Camera
# 46          0       1  0.38       1       T  Camera
# 50          0       1  0.38       1       T  Camera
# 51          0       1  0.38       1       T  Camera
# 54          0       1  0.39       1       T  Camera
# 58          0       1  0.41       1       T  Camera
# 59          0       1  0.41       1       T  Camera
# 75          0       1  0.58       1       T  Camera
# 76          0       1  0.58       1       T  Camera
# ...

# %%
player1[player1.event == 'Selection']
# Out:
#       game_id  winner  time  player species      event  \
# 57          0       1  0.40       1       T  Selection
# 130         0       1  1.23       1       T  Selection
# 141         0       1  1.30       1       T  Selection
# 146         0       1  1.37       1       T  Selection
# 183         0       1  2.12       1       T  Selection
# 210         0       1  2.24       1       T  Selection
# 213         0       1  2.25       1       T  Selection
# 262         0       1  2.44       1       T  Selection
# 312         0       1  2.53       1       T  Selection
# 313         0       1  2.53       1       T  Selection
# 326         0       1  2.59       1       T  Selection
# 343         0       1  3.12       1       T  Selection
# 344         0       1  3.12       1       T  Selection
# 347         0       1  3.15       1       T  Selection
# 387         0       1  3.23       1       T  Selection
# 388         0       1  3.23       1       T  Selection
# ...

# %%
player1[player1.event == 'Right Click']
# Out:
#       game_id  winner  time  player species        event  \
# 142         0       1  1.30       1       T  Right Click
# 250         0       1  2.40       1       T  Right Click
# 314         0       1  2.54       1       T  Right Click
# 331         0       1  3.01       1       T  Right Click
# 484         0       1  3.43       1       T  Right Click
# 554         0       1  4.03       1       T  Right Click
# 570         0       1  4.07       1       T  Right Click
# 571         0       1  4.07       1       T  Right Click
# 573         0       1  4.08       1       T  Right Click
# 574         0       1  4.09       1       T  Right Click
# 579         0       1  4.12       1       T  Right Click
# 587         0       1  4.14       1       T  Right Click
# 602         0       1  4.17       1       T  Right Click
# 607         0       1  4.19       1       T  Right Click
# 642         0       1  4.30       1       T  Right Click
# ...

# %%
player1[player1.event == 'GetControlGroup']
# Out:
#       game_id  winner  time  player species            event event_contents
# 945         0       1  6.06       1       T  GetControlGroup            NaN
# 950         0       1  6.08       1       T  GetControlGroup            NaN
# 1064        0       1  6.53       1       T  GetControlGroup            NaN

# %%
player1[player1.event == 'SetControlGroup']
# Out:
#      game_id  winner  time  player species            event event_contents
# 147        0       1  1.39       1       T  SetControlGroup            NaN

# %%
player1[player1.event == 'AddToControlGroup']
# Out:
# Empty DataFrame
# Columns: [game_id, winner, time, player, species, event, event_contents]
# Index: []

# %%
games100 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/games100.csv')
games100
# Out:
#         game_id  winner  time  player species            event  \
# 0             0       1  0.00       0       T           Camera
# 1             0       1  0.00       1       T           Camera
# 2             0       1  0.02       0       T        Selection
# 3             0       1  0.02       0       T          Ability
# 4             0       1  0.14       0       T           Camera
# ...         ...     ...   ...     ...     ...              ...
# 157885       99       0  4.31       1       Z  GetControlGroup
# 157886       99       0  4.31       1       Z        Selection
# 157887       99       0  4.31       0       Z  GetControlGroup
# 157888       99       0  4.31       1       Z  GetControlGroup
# 157889       99       0  4.31       1       Z        Selection
#
#                                            event_contents
# 0                                 at (145.25, 21.5078125)
# 1                                 at (22.75, 147.0078125)
# ...

# %%
games100[games100.event =='GetControlGroup']
# Out:
#         game_id  winner  time  player species            event event_contents
# 100           0       1  1.01       0       T  GetControlGroup            NaN
# 135           0       1  1.24       0       T  GetControlGroup            NaN
# 140           0       1  1.29       0       T  GetControlGroup            NaN
# 186           0       1  2.16       0       T  GetControlGroup            NaN
# 251           0       1  2.42       0       T  GetControlGroup            NaN
# ...         ...     ...   ...     ...     ...              ...            ...
# 157875       99       0  4.30       1       Z  GetControlGroup            NaN
# 157880       99       0  4.30       1       Z  GetControlGroup            NaN
# 157885       99       0  4.31       1       Z  GetControlGroup            NaN
# 157887       99       0  4.31       0       Z  GetControlGroup            NaN
# 157888       99       0  4.31       1       Z  GetControlGroup            NaN
#
# [22097 rows x 7 columns]

# %%
games100 = games100.fillna('NaN')

# %%
unitstrained = games100[games100.event_contents.str.contains('Train')]
unitstrained
# Out:
#         game_id  winner  time  player species    event          event_contents
# 3             0       1  0.02       0       T  Ability       (1360) - TrainSCV
# 29            0       1  0.33       1       T  Ability       (1360) - TrainSCV
# 37            0       1  0.35       0       T  Ability       (1360) - TrainSCV
# 63            0       1  0.41       1       T  Ability       (1360) - TrainSCV
# 101           0       1  1.03       0       T  Ability       (1360) - TrainSCV
# ...         ...     ...   ...     ...     ...      ...                     ...
# 156424       98       0  6.23       0       P  Ability     (15E0) - TrainProbe
# 156426       98       0  6.23       1       P  Ability  (15C3) - TrainImmortal
# 156492       98       0  6.35       0       P  Ability     (15E0) - TrainProbe
# 156618       98       0  6.55       0       P  Ability     (15E0) - TrainProbe
# 157748       99       0  4.07       0       Z  Ability     (1E60) - TrainQueen
#
# [2395 rows x 7 columns]

# %%
print(unitstrained.event_contents[3], len(unitstrained.event_contents[3]))
# Out:
# (1360) - TrainSCV 17

# %%
unitstrained.event_contents[3][14:]
# Out:
# 'SCV'

# %%
unitstrained.event_contents[157748][14:]
# Out:
# 'Queen'

# %%
set(games100[games100.event == 'Ability'].event_contents)
# Out:
# {'(5A0) - Attack; Target: Queen [042C0001]; Location: (138.4306640625, 29.436767578125, 40912)',
#  '(DE0) - SpawnLarva; Target: Hatchery [03A80001]; Location: (105.5, 163.5, 40912)',
#  '(127E)',
#  '(5A0) - Attack; Location: (156.212646484375, 15.426025390625, 49136)',
#  '(5A0) - Attack; Target: Overlord [03840001]; Location: (88.245849609375, 110.3125, 48212)',
#  '(12A1) - BuildFactoryReactor; Location: (33.5, 24.5, 49104)',
#  '(5A0) - Attack; Location: (128.45166015625, 67.138671875, 40928)',
#  '(5A0) - Attack; Location: (136.994384765625, 49.052490234375, 40935)',
#  '(5A0) - Attack; Location: (147.591796875, 70.2109375, 40941)',
#  '(5A0) - Attack; Location: (27.35986328125, 103.0576171875, 40941)',
#  '(1AC1) - WarpInStalker; Location: (135.240478515625, 51.740966796875, 40935)',
#  '(5A0) - Attack; Location: (42.138916015625, 88.088623046875, 40928)',
#  '(4C1) - Patrol; Location: (53.247802734375, 110.97265625, 32748)',
# ...

# %%
spells = ['ChronoBoost','CalldownMULE']
games100[games100.event_contents.str.contains('|'.join(spells))]
# '|'.join(spells)
# Out:
#         game_id  winner   time  player species    event  \
# 1048          0       1   6.45       0       T  Ability
# 1066          0       1   6.56       1       T  Ability
# 1909          1       1   3.14       1       T  Ability
# 2412          1       1   5.27       0       P  Ability
# 2513          1       1   5.51       1       T  Ability
# 3496          1       1   9.40       0       P  Ability
# 4173          2       0   3.10       0       P  Ability
# 4190          2       0   3.17       0       P  Ability
# 4304          2       0   3.56       0       P  Ability
# 4596          2       0   5.07       0       P  Ability
# 5567          2       0   9.06       0       P  Ability
# 6703          3       0   3.02       1       P  Ability
# 7019          3       0   4.03       1       P  Ability
# 7060          3       0   4.13       0       T  Ability
# 7426          3       0   5.18       1       P  Ability
# 7804          3       0   6.37       0       T  Ability
# ...

# %%
games300 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/games300.csv')

# %%
games300.shape
# Out:
# (510606, 7)

# %%
set(games300.event)
# Out:
# {'Ability',
#  'AddToControlGroup',
#  'Camera',
#  'ControlGroup',
#  'GetControlGroup',
#  'Right Click',
#  'Selection',
#  'SetControlGroup'}

# %%
games300[games300.game_id==299]
# Out:
#         game_id  winner  time  player species            event  \
# 508852      299       0  0.00       0       P           Camera
# 508853      299       0  0.00       1       Z           Camera
# 508854      299       0  0.01       0       P        Selection
# 508855      299       0  0.01       0       P          Ability
# 508856      299       0  0.01       1       Z        Selection
# ...         ...     ...   ...     ...     ...              ...
# 510601      299       0  5.30       0       P  GetControlGroup
# 510602      299       0  5.30       1       Z        Selection
# 510603      299       0  5.31       0       P           Camera
# 510604      299       0  5.31       0       P  GetControlGroup
# 510605      299       0  5.31       0       P           Camera
#
#                       event_contents
# 508852         at (28.0, 18.5078125)
# 508853       at (140.0, 162.0078125)
# 508854           ['Nexus [3000001]']
# 508855           (15E0) - TrainProbe
# ...

# %%
games100[games100.event_contents.str.contains('Build')]
# Out:
#         game_id  winner  time  player species    event  \
# 19            0       1  0.27       0       T  Ability
# 43            0       1  0.37       1       T  Ability
# 56            0       1  0.40       1       T  Ability
# 87            0       1  1.00       0       T  Ability
# 104           0       1  1.09       0       T  Ability
# ...         ...     ...   ...     ...     ...      ...
# 156542       98       0  6.42       0       P  Ability
# 156882       99       0  1.11       1       Z  Ability
# 157019       99       0  1.52       1       Z  Ability
# 157281       99       0  2.45       0       Z  Ability
# 157399       99       0  3.04       1       Z  Ability
#
#                                            event_contents
# 19      (1021) - BuildSupplyDepot; Location: (135.0, 4...
# 43      (1021) - BuildSupplyDepot; Location: (28.0, 14...
# 56      (1022) - BuildRefinery; Target: CreepOnlyBlock...
# 87      (1023) - BuildBarracks; Location: (135.5, 39.5...
# ...

# %%
s = games100.iloc[19].event_contents
s
# Out:
# '(1021) - BuildSupplyDepot; Location: (135.0, 42.0, 49119)'

# %%
s.split('d')[1].split(';')[0]
# Out:
# 'SupplyDepot'

# %%
# games100[~games100.event_contents.str.contains('Build')]
ability = games100[games100.event == 'Ability']
ability
# Out:
#         game_id  winner  time  player species    event  \
# 3             0       1  0.02       0       T  Ability
# 19            0       1  0.27       0       T  Ability
# 27            0       1  0.31       0       T  Ability
# 29            0       1  0.33       1       T  Ability
# 37            0       1  0.35       0       T  Ability
# ...         ...     ...   ...     ...     ...      ...
# 157806       99       0  4.22       1       Z  Ability
# 157809       99       0  4.23       0       Z  Ability
# 157860       99       0  4.29       1       Z  Ability
# 157864       99       0  4.29       1       Z  Ability
# 157879       99       0  4.30       0       Z  Ability
#
#                                            event_contents
# 3                                       (1360) - TrainSCV
# 19      (1021) - BuildSupplyDepot; Location: (135.0, 4...
# 27                                           (480) - Stop
# 29                                      (1360) - TrainSCV
# ...

# %%
ability[ability.species =='P']
# Out:
#         game_id  winner  time  player species    event  \
# 1192          1       1  0.12       0       P  Ability
# 1213          1       1  0.24       0       P  Ability
# 1233          1       1  0.31       0       P  Ability
# 1298          1       1  0.53       0       P  Ability
# 1311          1       1  0.57       0       P  Ability
# ...         ...     ...   ...     ...     ...      ...
# 156483       98       0  6.34       0       P  Ability
# 156492       98       0  6.35       0       P  Ability
# 156542       98       0  6.42       0       P  Ability
# 156603       98       0  6.51       0       P  Ability
# 156618       98       0  6.55       0       P  Ability
#
#                                            event_contents
# 1192                                  (15E0) - TrainProbe
# 1213    (1541) - BuildPylon; Location: (135.0, 167.0, ...
# 1233                                  (15E0) - TrainProbe
# 1298    (1543) - BuildGateway; Location: (133.5, 164.5...
# ...

# %%
notbuilding = ability[~ability.event_contents.str.contains('Build')]
trainmorph = 'Stop|Train|Morph|Attack|SetWorkerRally|ExtraSupplies|Evolve|Research|HoldPosition|ReturnCargo|Lift|LowerSupplyDepot|Raise|Land|Patrol|CancelLast|CancelSlot|Repair|Gather'

nottrain = notbuilding[~notbuilding.event_contents.str.contains(trainmorph)]
pd.options.display.max_columns = None
pd.options.display.max_rows = 2000
nottrain
# Out:
#         game_id  winner   time  player species    event  \
# 252           0       1   2.43       0       T  Ability
# 336           0       1   3.06       1       T  Ability
# 561           0       1   4.06       0       T  Ability
# 894           0       1   5.48       1       T  Ability
# 1034          0       1   6.36       0       T  Ability
# 1048          0       1   6.45       0       T  Ability
# 1060          0       1   6.52       1       T  Ability
# 1066          0       1   6.56       1       T  Ability
# 1909          1       1   3.14       1       T  Ability
# 2215          1       1   4.39       1       T  Ability
# 2252          1       1   4.48       1       T  Ability
# 2317          1       1   5.04       0       P  Ability
# 2412          1       1   5.27       0       P  Ability
# 2513          1       1   5.51       1       T  Ability
# 2592          1       1   6.22       1       T  Ability
# 2617          1       1   6.28       0       P  Ability
# ...

# %%
games300 = games300.fillna('NaN')

# %%
games300[games300.event_contents.str.contains('Cancel')] #decloack, cloack Extrasupplies : E20
# Out:
#         game_id  winner   time  player species    event  \
# 1035          0       1   6.38       0       T  Ability
# 1530          1       1   1.49       0       P  Ability
# 2195          1       1   4.33       1       T  Ability
# 2558          1       1   6.14       0       P  Ability
# 3560          1       1   9.55       0       P  Ability
# 8162          3       0   7.45       0       T  Ability
# 10138         4       0   4.44       0       T  Ability
# 10721         5       0   1.58       1       P  Ability
# 12518         6       1   1.19       0       P  Ability
# 12630         6       1   1.44       1       T  Ability
# 13103         6       1   3.23       0       P  Ability
# 14149         6       1   7.06       1       T  Ability
# 14228         7       0   0.23       0       Z  Ability
# 14646         7       0   2.12       1       P  Ability
# 16280         8       1   4.06       0       T  Ability
# 18271        10       0   1.50       0       P  Ability
# ...

# %%
spells = """ForceField
GuardianShield
Hallucination
Feedback
PsionicStorm
GravitonBeam
Revelation
Cloak|Decloack
EMPRound
BuildAutoTurret
CalldownMULE
ExtraSupplies
ScannerSweep
SpawnLarva
BuildCreepTumor
QueenTransfusion
SpawnChangeling
Contaminate
MassRecall
BuildOracleStasisTrap
OracleWeapon
OracleWeaponOff

Time Warp
Strategic Recall
Battery Overcharge
Steady Targeting
Anti-Armor Missile
Fungal Growth
Microbial Shroud
Blinding Cloud
Parasitic Bomb
Abduct




"""

# %%
spells = spells.replace('\n','|')

# %%
spells
# Out:
# 'ForceField|GuardianShield|Hallucination|Feedback|PsionicStorm|GravitonBeam|Revelation|Cloak|Decloack|EMPRound|BuildAutoTurret|CalldownMULE|ExtraSupplies|ScannerSweep|SpawnLarva|BuildCreepTumor|QueenTransfusion|SpawnChangeling|Contaminate|MassRecall|BuildOracleStasisTrap|OracleWeapon|OracleWeaponOff||Time Warp|Strategic Recall|Battery Overcharge|Steady Targeting|Anti-Armor Missile|Fungal Growth|Microbial Shroud|Blinding Cloud|Parasitic Bomb|Abduct|||||'

# %%
gamedata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/gamedata.csv')
gamedata
# Out:
#           game_id  winner  time  player species            event  \
# 0           30001       0  0.00       1       P           Camera
# 1           30001       0  0.00       0       Z           Camera
# 2           30001       0  0.01       1       P        Selection
# 3           30001       0  0.01       1       P          Ability
# 4           30001       0  0.01       0       Z        Selection
# ...           ...     ...   ...     ...     ...              ...
# 15374875    38871       0  8.51       0       Z           Camera
# 15374876    38871       0  8.52       1       T  GetControlGroup
# 15374877    38871       0  8.52       0       Z           Camera
# 15374878    38871       0  8.52       0       Z           Camera
# 15374879    38871       0  8.52       1       T          Ability
#
#                           event_contents
# 0                at (145.25, 21.5078125)
# 1                at (22.75, 147.0078125)
# 2                    ['Nexus [34C0001]']
# ...

# %%
gamedata = gamedata.fillna('NaN')

# %%
gamedata[(gamedata.event =='Ability') &(gamedata.event_contents.str.contains('Fungal'))]
# Out:
#           game_id  winner   time  player species    event  \
# 8504        30006       0   5.48       0       T  Ability
# 74998       30043       0   6.29       0       T  Ability
# 100554      30056       1   5.40       0       T  Ability
# 100609      30056       1   5.47       0       T  Ability
# 100629      30056       1   5.53       0       T  Ability
# 100737      30056       1   6.11       0       T  Ability
# 100744      30056       1   6.13       0       T  Ability
# 113672      30062       1   5.27       0       T  Ability
# 113789      30062       1   6.01       0       T  Ability
# 145423      30081       1   4.34       0       T  Ability
# 145617      30081       1   5.19       1       T  Ability
# 145656      30081       1   5.26       0       T  Ability
# 145661      30081       1   5.27       1       T  Ability
# 247194      30142       0   6.33       1       T  Ability
# 271071      30155       0   4.34       0       P  Ability
# ...

# %%
ex0 = games100[(games100.game_id ==99) & (games100.player==0)]

# %%
ex0.event.value_counts()
# Out:
# Camera             238
# Right Click        129
# Selection           90
# GetControlGroup     56
# Ability             22
# SetControlGroup      6
# Name: event, dtype: int64

# %%
type(ex0.event.value_counts())
# Out:
# pandas.core.series.Series

# %%
ex0.columns
# Out:
# Index(['game_id', 'winner', 'time', 'player', 'species', 'event',
#        'event_contents'],
#       dtype='object')

# %%
a = ex0.groupby('player',as_index=False).agg({
    'game_id': 'first',
    'winner': 'first', 
    'time':'last', 
    'species' : 'first', 
    'event' : ','.join,
    'event_contents':'first'
    # 'Platform':','.join,
    })
a
# Out:
#    player  game_id  winner  time species  \
# 0       0       99       0  4.31       Z
#
#                                                event           event_contents
# 0  Camera,Ability,Selection,Right Click,Right Cli...  at (151.25, 20.5078125)

# %%
# b = pd.DataFrame(pd.Series(a.event[0].split(',')).value_counts()).T
b = pd.Series(a.event[0].split(',')).value_counts()
b
# Out:
# Camera             238
# Right Click        129
# Selection           90
# GetControlGroup     56
# Ability             22
# SetControlGroup      6
# dtype: int64

# %%
b.index
# Out:
# Index(['Camera', 'Right Click', 'Selection', 'GetControlGroup', 'Ability',
#        'SetControlGroup'],
#       dtype='object')

# %%
a = a.drop(['event','event_contents'],axis=1)
a
# Out:
#    player  game_id  winner  time species
# 0       0       99       0  4.31       Z

# %%
b['Camera']
# Out:
# 238

# %%
for i in b.index:
  # print(i)
  a[f'player_{0}_'+i] = b[i]
  # print(b[i][0])
a
# Out:
#    player  game_id  winner  time species  player_0_Camera  \
# 0       0       99       0  4.31       Z              238
#
#    player_0_Right Click  player_0_Selection  player_0_GetControlGroup  \
# 0                   129                  90                        56
#
#    player_0_Ability  player_0_SetControlGroup
# 0                22                         6

# %%
numgames = list(set(games100.game_id))

# %%
events = ['Camera', 'Selection', 'Right Click', 'Ability', 'GetControlGroup', 'SetControlGroup', 'AddToControlGroup']

# %%
# games100
# for id in [0]:
#   tmp = []
# for player in [0,1]:
#   ex0 = games100[(games100.game_id == id ) & (games100.player==player )]
#   a = ex0.groupby('player',as_index=False).agg({
#       'game_id': 'first',
#       'winner': 'first', 
#       'time':'last', 
#       'species' : 'first', 
#       'event' : ','.join,
#       'event_contents':'first'
#       # 'Platform':','.join,
#       })
#   b = pd.Series(a.event[0].split(',')).value_counts()
#   a = a.drop(['player','event','event_contents','species'],axis=1)
#   for i in events:
#     a[f'player_{player}_'+i] = b[i]
# a

# %%
tmp = []
# numbers = 0~ 38800 몇
ex0 = games100[(games100.game_id == 0 ) & (games100.player== 0 )]
initial = ex0.groupby('player',as_index=False).agg({
    'game_id': 'first',
    'winner': 'first', 
    'time':'last', 
    'species' : 'first', 
    'event' : ','.join,
    'event_contents':'first'
    # 'Platform':','.join,
    })
b = pd.Series(initial.event[0].split(',')).value_counts()
initial['player_0_species'] = initial['species']
initial = initial.drop(['player','event','event_contents','species'],axis=1)
for i in events:
  initial[f'player_{0}_'+i] = b[i]
b
# Out:
# Camera               444
# Selection             50
# Right Click           35
# Ability               34
# GetControlGroup       24
# SetControlGroup        3
# AddToControlGroup      2
# dtype: int64

# %%
ex0 = games100[(games100.game_id == 0 ) & (games100.player== 1 )]
a = ex0.groupby('player',as_index=False).agg({
    'game_id': 'first',
    'winner': 'first', 
    'time':'last', 
    'species' : 'first', 
    'event' : ','.join,
    'event_contents':'first'
    # 'Platform':','.join,
    })
b = pd.Series(a.event[0].split(',')).value_counts()
initial['player_1_species'] = a['species']
a = a.drop(['player','event','event_contents','species'],axis=1)
for i in events:
  if i not in b.index:
    initial[f'player_{1}_'+i] = 0 
    continue 
  initial[f'player_{1}_'+i] = b[i]
initial.T
# Out:
#                                0
# game_id                        0
# winner                         1
# time                        7.24
# player_0_species               T
# player_0_Camera              444
# player_0_Selection            50
# player_0_Right Click          35
# player_0_Ability              34
# player_0_GetControlGroup      24
# player_0_SetControlGroup       3
# player_0_AddToControlGroup     2
# player_1_species               T
# player_1_Camera              425
# player_1_Selection            57
# player_1_Right Click          28
# player_1_Ability              34
# player_1_GetControlGroup       3
# player_1_SetControlGroup       1
# player_1_AddToControlGroup     0

# %%
games100[games100.game_id ==3]
# Out:
#       game_id  winner  time  player species        event  \
# 5796        3       0  0.00       0       T       Camera
# 5797        3       0  0.00       1       P       Camera
# 5798        3       0  0.01       0       T    Selection
# 5799        3       0  0.01       0       T      Ability
# 5800        3       0  0.01       1       P    Selection
# ...       ...     ...   ...     ...     ...          ...
# 8802        3       0  9.58       0       T  Right Click
# 8803        3       0  9.58       0       T  Right Click
# 8804        3       0  9.59       0       T       Camera
# 8805        3       0  9.59       0       T       Camera
# 8806        3       0  9.59       0       T       Camera
#
#                                          event_contents
# 5796                            at (127.25, 27.5078125)
# 5797                            at (24.75, 137.0078125)
# 5798                       ['OrbitalCommand [3380001]']
# ...

# %%
ex0 = games100[(games100.game_id == 4 ) & (games100.player== 1 )]
tmp1 = ex0.groupby('player',as_index=False).agg({
    'game_id': 'first',
    'winner': 'first', 
    'time':'last', 
    'species' : 'first', 
    'event' : ','.join,
    'event_contents':'first'
    # 'Platform':','.join,
    })
tmp1
# Out:
#    player  game_id  winner  time species  \
# 0       1        4       0  5.43       Z
#
#                                                event           event_contents
# 0  Camera,Selection,Ability,Selection,SetControlG...  at (163.25, 18.5078125)

# %%
b = pd.Series(tmp1.event[0].split(',')).value_counts()
b
# Out:
# Camera               272
# Selection            126
# Right Click          106
# GetControlGroup       99
# Ability               36
# SetControlGroup        8
# AddToControlGroup      4
# dtype: int64

# %%
|'AddToControlGroup' in b.index
# Out:
# False

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/gamedata10000.csv')
data[1:7].T
# Out:
#                                1     2     3     4     5     6
# game_id                        1     2     3     1     2     3
# winner                         1     0     0     1     0     0
# time                        9.59  9.59  9.59  9.59  9.59  9.59
# player_0_species               P     P     T     P     P     T
# player_0_Camera              627   413   713   627   413   713
# player_0_Selection           186    90   180   186    90   180
# player_0_Right Click         160   160   276   160   160   276
# player_0_Ability              77    69    82    77    69    82
# player_0_GetControlGroup     162    99   132   162    99   132
# player_0_SetControlGroup      10    14     6    10    14     6
# player_0_AddToControlGroup     1     6     0     1     6     0
# player_1_species             NaN   NaN   NaN     T     Z     P
# player_1_Camera              627   413   713   858   725   388
# player_1_Selection           186    90   180   116   232   148
# ...

# %%
data.isnull().sum()
# Out:
# game_id                       0
# winner                        0
# time                          0
# player_0_species              0
# player_0_Camera               0
# player_0_Selection            0
# player_0_Right Click          0
# player_0_Ability              0
# player_0_GetControlGroup      0
# player_0_SetControlGroup      0
# player_0_AddToControlGroup    0
# player_1_species              3
# player_1_Camera               0
# player_1_Selection            0
# player_1_Right Click          0
# player_1_Ability              0
# player_1_GetControlGroup      0
# player_1_SetControlGroup      0
# player_1_AddToControlGroup    0
# dtype: int64

# %%
data.drop(index = [1,2,3])
# Out:
#        game_id  winner  time player_0_species  player_0_Camera  \
# 0            0       1  7.24                T              444
# 4            1       1  9.59                P              627
# 5            2       0  9.59                P              413
# 6            3       0  9.59                T              713
# 7            4       0  5.39                T              430
# ...        ...     ...   ...              ...              ...
# 9998      9995       0  6.37                P              456
# 9999      9996       0  6.59                T              295
# 10000     9997       0  9.59                Z              773
# 10001     9998       1  3.41                T              214
# 10002     9999       0  9.51                Z              324
#
#        player_0_Selection  player_0_Right Click  player_0_Ability  \
# 0                      50                    35                34
# 4                     186                   160                77
# ...

# %%
tmp = data.drop(index = [1,2,3]).reset_index().iloc[:,1:]
tmp
# Out:
#       game_id  winner  time player_0_species  player_0_Camera  \
# 0           0       1  7.24                T              444
# 1           1       1  9.59                P              627
# 2           2       0  9.59                P              413
# 3           3       0  9.59                T              713
# 4           4       0  5.39                T              430
# ...       ...     ...   ...              ...              ...
# 9995     9995       0  6.37                P              456
# 9996     9996       0  6.59                T              295
# 9997     9997       0  9.59                Z              773
# 9998     9998       1  3.41                T              214
# 9999     9999       0  9.51                Z              324
#
#       player_0_Selection  player_0_Right Click  player_0_Ability  \
# 0                     50                    35                34
# 1                    186                   160                77
# ...

# %%
games100.drop(index = games100[games100.game_id==0].index)
# Out:
#         game_id  winner  time  player species            event  \
# 1140          1       1  0.00       1       T           Camera
# 1141          1       1  0.00       0       P           Camera
# 1142          1       1  0.00       1       T        Selection
# 1143          1       1  0.01       0       P        Selection
# 1144          1       1  0.01       1       T          Ability
# ...         ...     ...   ...     ...     ...              ...
# 157885       99       0  4.31       1       Z  GetControlGroup
# 157886       99       0  4.31       1       Z        Selection
# 157887       99       0  4.31       0       Z  GetControlGroup
# 157888       99       0  4.31       1       Z  GetControlGroup
# 157889       99       0  4.31       1       Z        Selection
#
#                                            event_contents
# 1140                                at (28.0, 18.5078125)
# 1141                              at (140.0, 162.0078125)
# ...

# %%
games100
# Out:
#         game_id  winner  time  player species            event  \
# 0             0       1  0.00       0       T           Camera
# 1             0       1  0.00       1       T           Camera
# 2             0       1  0.02       0       T        Selection
# 3             0       1  0.02       0       T          Ability
# 4             0       1  0.14       0       T           Camera
# ...         ...     ...   ...     ...     ...              ...
# 157885       99       0  4.31       1       Z  GetControlGroup
# 157886       99       0  4.31       1       Z        Selection
# 157887       99       0  4.31       0       Z  GetControlGroup
# 157888       99       0  4.31       1       Z  GetControlGroup
# 157889       99       0  4.31       1       Z        Selection
#
#                                            event_contents
# 0                                 at (145.25, 21.5078125)
# 1                                 at (22.75, 147.0078125)
# ...

# %%
data20000 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/gamedata20000.csv')

# %%
tmp
# Out:
#       game_id  winner  time player_0_species  player_0_Camera  \
# 0           0       1  7.24                T              444
# 1           1       1  9.59                P              627
# 2           2       0  9.59                P              413
# 3           3       0  9.59                T              713
# 4           4       0  5.39                T              430
# ...       ...     ...   ...              ...              ...
# 9995     9995       0  6.37                P              456
# 9996     9996       0  6.59                T              295
# 9997     9997       0  9.59                Z              773
# 9998     9998       1  3.41                T              214
# 9999     9999       0  9.51                Z              324
#
#       player_0_Selection  player_0_Right Click  player_0_Ability  \
# 0                     50                    35                34
# 1                    186                   160                77
# ...

# %%
data20000
# Out:
#        game_id  winner   time player_0_species  player_0_Camera  \
# 0        10000       1   9.59                T              973
# 1        10001       0  10.21                T              725
# 2        10002       0   9.59                Z              686
# 3        10003       1   3.11                P              120
# 4        10004       1   3.54                P              156
# ...        ...     ...    ...              ...              ...
# 9996     19996       1   8.30                Z              334
# 9997     19997       0   4.31                P              266
# 9998     19998       1   5.15                Z              228
# 9999     19999       1   9.59                P              468
# 10000    20000       1   9.58                Z              899
#
#        player_0_Selection  player_0_Right Click  player_0_Ability  \
# 0                      92                   109                74
# ...

# %%
data20000.isnull().sum().sum()
# Out:
# 0

# %%
tmp = tmp.append(data20000)

# %%
tmp.winner.value_counts(normalize=True)
# Out:
# 1    0.500125
# 0    0.499875
# Name: winner, dtype: float64

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20001 entries, 0 to 10000
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   game_id                     20001 non-null  int64
#  1   winner                      20001 non-null  int64
#  2   time                        20001 non-null  float64
#  3   player_0_species            20001 non-null  object
#  4   player_0_Camera             20001 non-null  int64
#  5   player_0_Selection          20001 non-null  int64
#  6   player_0_Right Click        20001 non-null  int64
#  7   player_0_Ability            20001 non-null  int64
#  8   player_0_GetControlGroup    20001 non-null  int64
#  9   player_0_SetControlGroup    20001 non-null  int64
#  10  player_0_AddToControlGroup  20001 non-null  int64
#  11  player_1_species            20001 non-null  object
#  12  player_1_Camera             20001 non-null  int64
# ...

# %%
tmp[(tmp.player_0_species == 'Z') & (tmp.player_1_species == 'Z')].winner.value_counts(normalize=True)
# Out:
# 0    0.511989
# 1    0.488011
# Name: winner, dtype: float64

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/gamedata30000.csv')
# Out:
#       game_id  winner  time player_0_species  player_0_Camera  \
# 0       20001       0  9.59                T              674
# 1       20002       1  5.55                Z              141
# 2       20003       1  9.58                Z              517
# 3       20004       0  8.34                T              415
# 4       20005       1  7.53                P              274
# ...       ...     ...   ...              ...              ...
# 9994    29995       0  9.59                Z              379
# 9995    29996       1  0.50                Z               26
# 9996    29997       0  9.58                Z              661
# 9997    29998       1  9.35                P              548
# 9998    29999       1  9.59                T              266
#
#       player_0_Selection  player_0_Right Click  player_0_Ability  \
# 0                     95                    57                79
# 1                     71                    70                31
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/gamedata10000.csv')
complete_data = data.drop(index = [1,2,3]).reset_index().iloc[:,1:]
complete_data
# Out:
#       game_id  winner  ...  player_1_SetControlGroup player_1_AddToControlGroup
# 0           0       1  ...                         1                          0
# 1           1       1  ...                         8                          0
# 2           2       0  ...                         9                          5
# 3           3       0  ...                        19                          0
# 4           4       0  ...                         8                          4
# ...       ...     ...  ...                       ...                        ...
# 9995     9995       0  ...                         0                          2
# 9996     9996       0  ...                         0                          0
# 9997     9997       0  ...                         1                          0
# 9998     9998       1  ...                         5                          0
# 9999     9999       0  ...                         0                          4
#
# ...

# %%
for i in [20000, 30000, 38871]:
  complete_data = complete_data.append(pd.read_csv(f'/content/drive/MyDrive/Colab Notebooks/Project_section2/gamedata{i}.csv'))
complete_data
# Out:
#       game_id  winner  ...  player_1_SetControlGroup player_1_AddToControlGroup
# 0           0       1  ...                         1                          0
# 1           1       1  ...                         8                          0
# 2           2       0  ...                         9                          5
# 3           3       0  ...                        19                          0
# 4           4       0  ...                         8                          4
# ...       ...     ...  ...                       ...                        ...
# 8867    38867       1  ...                         0                          0
# 8868    38868       0  ...                         3                          0
# 8869    38869       0  ...                         6                          2
# 8870    38870       1  ...                         5                          0
# 8871    38871       0  ...                        11                          0
#
# ...

# %%
complete_data.to_csv('/content/drive/MyDrive/Colab Notebooks/Project_section2/project2_data_sc2.csv', sep=',', index=False)
